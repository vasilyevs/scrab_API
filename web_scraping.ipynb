# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup

# %%
# метод get
habr = requests.get('https://habr.com/ru/all/')

# res
habr.status_code
# Out:
# 200

# %%
habr.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" class="no-js">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<meta content=\'width=1024\' name=\'viewport\'>\n<title>Все публикации подряд / Хабр</title>\n\n\n\n  <meta property="fb:app_id" content="444736788986613" />\n<meta property="og:type" content="website"/>\n<meta property="fb:pages" content="472597926099084"/>\n<meta property="og:site_name" content="Хабр" />\n<link rel="image_src" href="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image" content="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image:width" content="1200" />\n<meta property="og:image:height" content="628" />\n<meta property="og:title" content="Все публикации подряд / Хабр"/>\n<meta property="og:description" content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом."/>\n\n\n\n<meta name=\'yandex-verification\' content=\'71593b225aeafc4e\' />\n<meta name=\'referrer\' content=\'unsafe-url\' />\n<meta name="pocket-site-verification" content="ed24b2b9721edf0a282c5b4a3232c4" />\n<meta name="biu" content="https://dr.habracdn.net/habr/oldassets/60a75345/images/">\n\n<style type="text/css">\n  @font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}\n</style>\n\n<link href="https://dr.habracdn.net/habr/oldassets/60a75345/styles/main.bundle.css" rel="stylesheet" media="all" />\n\n\n\n\n\n<meta name=\'yandex-verification\' content=\'67d46b975fa41645\' />\n\n<link rel="apple-touch-icon" sizes="180x180" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/apple-touch-icon.png">\n<link rel="icon" type="image/png" sizes="32x32" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-32x32.png">\n<link rel="icon" type="image/png" sizes="16x16" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-16x16.png">\n<link rel="manifest" href="https://dr.habracdn.net/habr/oldassets/60a75345/site.webmanifest">\n<link rel="mask-icon" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/safari-pinned-tab.svg" color="#77a2b6">\n<meta name="application-name" content="Хабр"/>\n<meta name="msapplication-TileColor" content="#77a2b6">\n<meta name="theme-color" content="#77a2b6">\n\n\n  <link title="Все публикации подряд" type="application/rss+xml" rel="alternate" href="https://habr.com/ru/rss/all/all/?fl=ru"/>\n\n<script>/* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){\'use strict\';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}\nfunction r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a ...

# %%
KEYWORDS = ['python', 'парсинг']

# %%
soup = BeautifulSoup(habr.text, 'html.parser')

# %%
# добираемся до блоков с новостями
posts = soup.find_all('h2', class_='post__title')
posts
# Out:
# [<h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/skillfactory/blog/558672/">3 способа визуального извлечения данных с помощью JavaScript</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559228/">Как я хотел поработать нативным Android разработчиком, но устроился Flutter разрабом</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/englishdom/blog/559100/">Good vs. Well, или Гайд о прилагательных и наречиях в английском языке</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/selectel/blog/555948/">Процессорам Alder Lake от Intel понадобятся новые системы охлаждения и материнские платы</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559220/">Deepfake. Реализация технологии замены лиц в видео. Часть 1</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/deutschetelekomitsolutions/blog/559214/">«Главное – мотивированность и настойчивость»: как в Deutsche Telekom IT Solutions растят своих специалистов</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559212/">Как баг с потерянными днями рождения привёл нас в историю СССР</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/wrike/blog/558070/">Как превратиться в суперзвезду Zoom-звонков за 15 минут. Часть 2. Софт</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/otus/blog/559210/">Создание функции губки из MD5</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/ruvds/blog/559148/">Рояль над котиком, день первый</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/otus/blog/559170/">Анонсирование HAProxy Kubernetes Ingress Controller 1.5</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/otus/blog/559176/">fork() — зло; vfork() — добро; afork() — лучше; clone () — глупо</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/microsoft/blog/559174/">Microsoft Build 2021 — прямая трансляция на русском языке (начало в 18:45 МСК)</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559146/">Дистанционная (удалённая) работа IT-специалистов: существенные условия трудового договора</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559050/">KeyClusterer 2.3 — Многопоточность, интеграция с Key Collector</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/selectel/blog/555824/">Антарктический ад: как в атмосфере Земли 430000 лет назад взорвался метеорит</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/559160/">Интеграция Shopify и MailChimp</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/ozontech/blog/557178/">Figma: плагины для продуктового дизайна. Локальный топчик с видео-инструкцией</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/celsus/blog/559150/">Разработка Computer Vision в онкологии: почему всегда нужно еще больше сил, времени и денег</a>
#  </h2>, <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/macloud/blog/559108/">5 приемов по разделению «бандла» и «ленивой» загрузке компонентов в React</a>
#  </h2>]

# %%
articles_links = list(map(lambda x: x.find('a').get('href'), posts))
articles_links
# Out:
# ['https://habr.com/ru/company/skillfactory/blog/558672/',
#  'https://habr.com/ru/post/559228/',
#  'https://habr.com/ru/company/englishdom/blog/559100/',
#  'https://habr.com/ru/company/selectel/blog/555948/',
#  'https://habr.com/ru/post/559220/',
#  'https://habr.com/ru/company/deutschetelekomitsolutions/blog/559214/',
#  'https://habr.com/ru/post/559212/',
#  'https://habr.com/ru/company/wrike/blog/558070/',
#  'https://habr.com/ru/company/otus/blog/559210/',
#  'https://habr.com/ru/company/ruvds/blog/559148/',
#  'https://habr.com/ru/company/otus/blog/559170/',
#  'https://habr.com/ru/company/otus/blog/559176/',
#  'https://habr.com/ru/company/microsoft/blog/559174/',
#  'https://habr.com/ru/post/559146/',
#  'https://habr.com/ru/post/559050/',
#  'https://habr.com/ru/company/selectel/blog/555824/',
#  'https://habr.com/ru/post/559160/',
#  'https://habr.com/ru/company/ozontech/blog/557178/',
#  'https://habr.com/ru/company/celsus/blog/559150/',
#  'https://habr.com/ru/company/macloud/blog/559108/']

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
kom_news = pd.DataFrame()
for link in articles_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    time.sleep(0.3)
    title = soup.find('title').text  
    text = soup.find(class_='post__body post__body_full').text
    date = pd.to_datetime(soup.find(class_='post__time').get('data-time_published'))
    row = {'date': date, 'title': title,'link': link, 'text': text}
    kom_news = pd.concat([kom_news, pd.DataFrame([row])])  
kom_news.reset_index()
# Out:
#     index                      date  \
# 0       0 2021-05-25 15:18:00+00:00
# 1       0 2021-05-25 14:56:00+00:00
# 2       0 2021-05-25 14:51:00+00:00
# 3       0 2021-05-25 14:38:00+00:00
# 4       0 2021-05-25 14:35:00+00:00
# 5       0 2021-05-25 14:16:00+00:00
# 6       0 2021-05-25 14:13:00+00:00
# 7       0 2021-05-25 14:12:00+00:00
# 8       0 2021-05-25 14:11:00+00:00
# 9       0 2021-05-25 14:01:00+00:00
# 10      0 2021-05-25 13:56:00+00:00
# 11      0 2021-05-25 13:49:00+00:00
# 12      0 2021-05-25 13:43:00+00:00
# 13      0 2021-05-25 13:16:00+00:00
# 14      0 2021-05-25 13:09:00+00:00
# 15      0 2021-05-25 12:31:00+00:00
# 16      0 2021-05-25 12:20:00+00:00
# 17      0 2021-05-25 12:07:00+00:00
# 18      0 2021-05-25 12:02:00+00:00
# 19      0 2021-05-25 12:00:00+00:00
#
#                                                 title  \
# 0   3 способа визуального извлечения данных с помо...
# 1   Как я хотел поработать нативным Android разраб...
# 2   Good vs. Well, или Гайд о прилагательных и нар...
# 3   Процессорам Alder Lake от Intel понадобятся но...
# 4   Deepfake. Реализация технологии замены лиц в в...
# 5   «Главное – мотивированность и настойчивость»: ...
# 6   Как баг с потерянными днями рождения привёл на...
# 7   Как превратиться в суперзвезду Zoom-звонков за...
# 8   Создание функции губки из MD5 / Блог компании ...
# 9   Рояль над котиком, день первый / Блог компании...
# 10  Анонсирование HAProxy Kubernetes Ingress Contr...
# 11  fork() — зло; vfork() — добро; afork() — лучше...
# 12  Microsoft Build 2021 — прямая трансляция на ру...
# 13  Дистанционная (удалённая) работа IT-специалист...
# 14  KeyClusterer 2.3 — Многопоточность, интеграция...
# 15  Антарктический ад: как в атмосфере Земли 43000...
# 16              Интеграция Shopify и MailChimp / Хабр
# 17  Figma: плагины для продуктового дизайна. Локал...
# 18  Разработка Computer Vision в онкологии: почему...
# 19  5 приемов по разделению «бандла» и «ленивой» з...
#
#                                                  link  \
# 0   https://habr.com/ru/company/skillfactory/blog/...
# 1                    https://habr.com/ru/post/559228/
# 2   https://habr.com/ru/company/englishdom/blog/55...
# 3   https://habr.com/ru/company/selectel/blog/555948/
# 4                    https://habr.com/ru/post/559220/
# 5   https://habr.com/ru/company/deutschetelekomits...
# 6                    https://habr.com/ru/post/559212/
# 7      https://habr.com/ru/company/wrike/blog/558070/
# 8       https://habr.com/ru/company/otus/blog/559210/
# 9      https://habr.com/ru/company/ruvds/blog/559148/
# 10      https://habr.com/ru/company/otus/blog/559170/
# 11      https://habr.com/ru/company/otus/blog/559176/
# 12  https://habr.com/ru/company/microsoft/blog/559...
# 13                   https://habr.com/ru/post/559146/
# 14                   https://habr.com/ru/post/559050/
# 15  https://habr.com/ru/company/selectel/blog/555824/
# 16                   https://habr.com/ru/post/559160/
# 17  https://habr.com/ru/company/ozontech/blog/557178/
# 18    https://habr.com/ru/company/celsus/blog/559150/
# 19   https://habr.com/ru/company/macloud/blog/559108/
#
#                                                  text
# 0   \nК старту курса о Frontend-разработке мы реши...
# 1   \nНебольшое вступлениеПосле праздничных канику...
# 2   \nСегодня мы поговорим о достаточно скользкой ...
# 3   \n\r\nСовсем недавно в нашем блоге публиковала...
# 4   \nВсем привет! Я работаю с генеративными модел...
# 5   \nКак выглядит типичный процесс отбора на стаж...
# 6   \nНа корпоративном портале одного нашего заказ...
# 7   \n«Ну наконец-то!» — услышал я от нескольких ч...
# 8   \nПривет, Хабр. В преддверии старта курса "Pyt...
# 9   \nЕсли вы ещё не слышали, вчера одна эксцентри...
# 10  \nПеревод статьи подготовлен в рамках курса «И...
# 11  \nНедавно я наткнулся на реализацию popen() (т...
# 12  \nКонференция Build – ключевое событие года дл...
# 13  \n\n\r\nЗначительная часть авторов и читателей...
# 14  \nВсем привет! В новой версии KeyClusterer нам...
# 15  \n\r\nГруппа ученых обнаружила свидетельства п...
# 16  \nShopify — сервис, который позволяет без знан...
# 17  \nДля Figma написан целый легион плагинов на в...
# 18  \n\n\nПривет!\n\nЯ Жека Никитин, Head of AI в ...
# 19  \n\nРазделение Javascript-кода на несколько фа...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
EMAIL = ['admin@gmail.com']

# %%
URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

# %%
params = {
'POST': '/v1/web/query/site-breaches/unauthorized-data HTTP/1.1',
'Host': 'identityprotection.avast.com',
'Connection': 'keep-alive',
'Content-Length': '41',
'Accept': 'application/json, text/plain, */*',
'Vaar-Header-App-Build-Version': '1.0.0',
'Vaar-Version': '0',
'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.96 Safari/537.36',
'Vaar-Header-App-Product': 'hackcheck-web-avast',
'Vaar-Header-App-Product-Name': 'hackcheck-web-avast',
'Content-Type': 'application/json;charset=UTF-8',
'Origin': 'https://www.avast.com',
'Sec-Fetch-Site': 'same-site',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Dest': 'empty',
'Referer': 'https://www.avast.com/',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'ru,en;q=0.9',
}

# %%
res = requests.post(URL, data = params)
res
# Out:
# <Response [400]>

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
